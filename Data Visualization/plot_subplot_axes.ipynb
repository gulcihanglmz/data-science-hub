# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = [1,2,3,4]   #-> it give y axis , x axis created according to y
plt.plot(x)
plt.show()

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
# defining table dimension
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.axis([0,6,0,20])   # [Xmin,Xmax , Ymin,Ymax]
plt.show()

# %%
plt.title("Graph Title")
plt.ylabel("Y label")
plt.xlabel("X label")
# Out:
# Text(0.5, 0, 'X label')

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y, color="red" , linewidth = 3)

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y, "g")

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y, ":g")

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y, "--g")

# %% [markdown]
# **Format :  [marker][line][color]**

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y, "o-r")

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y, "o--r")

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y, "or")

# %%
x = np.linspace(0,2,100)
plt.plot(x , x , label = "lineer")
plt.plot(x , x**2 , label = "quadratic")
plt.plot(x , x**3 , label = "cubic")
plt.xlabel("Xlabel")
plt.ylabel("Ylabel")
plt.title("Simple Plot")
plt.legend()
plt.show()

# %%
x = np.linspace(0,2,100)
fgr , axs = plt.subplots(2)
axs[0].plot(x,x,color="red")
axs[0].set_title("lineer")
axs[1].plot(x,x**2,color="green")
axs[1].set_title("quadratic")
plt.tight_layout()
#tight_layout: grafiklerin ve etiketlerin birbirine karışmaması için düzenlemeyi sıkı bir hale getirir.
plt.show()

# %%
x = np.linspace(0,2,100)
fig , axs = plt.subplots(2,2)  # 2 row, 2 column
fig.suptitle("Figure Title")
axs[0,0].plot(x,x,color="blue",linewidth=3)      #[0,0] : 0.row , 0.column
axs[0,1].plot(x,x**2,color="purple",linewidth=3)
axs[1,0].plot(x,x**3,color="red",linewidth=3)
axs[1,1].plot(x,x**4,color="pink",linewidth=3)

plt.show()

# %%
x = np.linspace(0,2,100)
fig , axs = plt.subplots(2,2)
fig.suptitle("Figure Title")

axs[0,0].plot(x,x,color="blue",linewidth=3)
axs[0,0].set_title("lineer")

axs[0,1].plot(x,x**2,color="purple",linewidth=3)
axs[0,1].set_title("qudratic")

axs[1,0].plot(x,x**3,color="red",linewidth=3)
axs[1,0].set_title("cubic")

axs[1,1].plot(x,x**4,color="pink",linewidth=3)
axs[1,1].set_title("quartic")

plt.show()
