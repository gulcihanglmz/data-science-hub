# %%
import pandas as pd

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/imdb.csv")

# %%
df.columns
# Out:
# Index(['Movie_Title', 'YR_Released', 'Rating', 'Num_Reviews', 'Movie_ID',
#        'Record', 'Runtime'],
#       dtype='object')

# %%
df.head()
# Out:
#                     Movie_Title  YR_Released  Rating  Num_Reviews   Movie_ID  \
# 0             Code Name: K.O.Z.         2015     1.4        24623  tt4458206
# 1              Saving Christmas         2014     1.5        12765  tt4009460
# 2  Superbabies: Baby Geniuses 2         2004     1.6        26505  tt0270846
# 3             Daniel the Wizard         2004     1.6        13295  tt0421051
# 4      Manos: The Hands of Fate         1966     1.7        31808  tt0060666
#
#               Record  Runtime
# 0  Bottom 250 Movies    114.0
# 1  Bottom 250 Movies     80.0
# 2  Bottom 250 Movies     88.0
# 3  Bottom 250 Movies     81.0
# 4  Bottom 250 Movies     70.0

# %%
df.head(10)
# Out:
#                      Movie_Title  YR_Released  Rating  Num_Reviews   Movie_ID  \
# 0              Code Name: K.O.Z.         2015     1.4        24623  tt4458206
# 1               Saving Christmas         2014     1.5        12765  tt4009460
# 2   Superbabies: Baby Geniuses 2         2004     1.6        26505  tt0270846
# 3              Daniel the Wizard         2004     1.6        13295  tt0421051
# 4       Manos: The Hands of Fate         1966     1.7        31808  tt0060666
# 5                   Pledge This!         2006     1.7        15836  tt0417056
# 6  Dünyayi Kurtaran Adam'in Oglu         2006     1.8        14110  tt0808240
# 7                     Foodfight!         2012     1.8         5740  tt0249516
# 8     Birdemic: Shock and Terror         2010     1.8        15919  tt1316037
# 9                       Álom.net         2009     1.9         8502  tt1309000
#
#               Record  Runtime
# 0  Bottom 250 Movies    114.0
# 1  Bottom 250 Movies     80.0
# ...

# %%
df.tail()
# Out:
#                                            Movie_Title  YR_Released  Rating  \
# 845  Pirates of the Caribbean: The Curse of the Bla...         2003     8.0
# 846                   What Ever Happened to Baby Jane?         1962     8.0
# 847                                       Paris, Texas         1984     8.0
# 848                                           Drishyam         2015     8.0
# 849                                                 PK         2014     8.0
#
#      Num_Reviews   Movie_ID          Record  Runtime
# 845       872441  tt0325980  Top 250 Movies    143.0
# 846        37906  tt0056687  Top 250 Movies    134.0
# 847        55587  tt0087884  Top 250 Movies    145.0
# 848        40777  tt4430212  Top 250 Movies    163.0
# 849       106375  tt2338151  Top 250 Movies    153.0

# %%
df.tail(10)
# Out:
#                                            Movie_Title  YR_Released  Rating  \
# 840                                           The Help         2011     8.0
# 841                               Beauty and the Beast         1991     8.0
# 842                                  Dog Day Afternoon         1975     8.0
# 843                              The Battle of Algiers         1966     8.0
# 844                               In the Mood for Love         2000     8.0
# 845  Pirates of the Caribbean: The Curse of the Bla...         2003     8.0
# 846                   What Ever Happened to Baby Jane?         1962     8.0
# 847                                       Paris, Texas         1984     8.0
# 848                                           Drishyam         2015     8.0
# 849                                                 PK         2014     8.0
#
#      Num_Reviews   Movie_ID          Record  Runtime
# 840       345567  tt1454029  Top 250 Movies    146.0
# ...

# %%
df["Movie_Title"].head()
# Out:
# 0               Code Name: K.O.Z.
# 1                Saving Christmas
# 2    Superbabies: Baby Geniuses 2
# 3               Daniel the Wizard
# 4        Manos: The Hands of Fate
# Name: Movie_Title, dtype: object

# %%
df[["Movie_Title", "Rating"]].head()
# Out:
#                     Movie_Title  Rating
# 0             Code Name: K.O.Z.     1.4
# 1              Saving Christmas     1.5
# 2  Superbabies: Baby Geniuses 2     1.6
# 3             Daniel the Wizard     1.6
# 4      Manos: The Hands of Fate     1.7

# %%
df[["Movie_Title", "Rating"]].tail(7)
# Out:
#                                            Movie_Title  Rating
# 843                              The Battle of Algiers     8.0
# 844                               In the Mood for Love     8.0
# 845  Pirates of the Caribbean: The Curse of the Bla...     8.0
# 846                   What Ever Happened to Baby Jane?     8.0
# 847                                       Paris, Texas     8.0
# 848                                           Drishyam     8.0
# 849                                                 PK     8.0

# %%
df[5:][["Movie_Title", "Rating"]].head()
# Out:
#                      Movie_Title  Rating
# 5                   Pledge This!     1.7
# 6  Dünyayi Kurtaran Adam'in Oglu     1.8
# 7                     Foodfight!     1.8
# 8     Birdemic: Shock and Terror     1.8
# 9                       Álom.net     1.9

# %%
df[df["Rating"] >= 8.0][["Movie_Title", "Rating"]].head()
# Out:
#                   Movie_Title  Rating
# 100  The Shawshank Redemption     9.2
# 101             The Godfather     9.2
# 102    The Godfather: Part II     9.0
# 103           The Dark Knight     9.0
# 104              12 Angry Men     8.9

# %%
df[(df["YR_Released"] >= 2014) | (df["YR_Released"] <= 2015)][["Movie_Title", "YR_Released"]].head()
# Out:
#                     Movie_Title  YR_Released
# 0             Code Name: K.O.Z.         2015
# 1              Saving Christmas         2014
# 2  Superbabies: Baby Geniuses 2         2004
# 3             Daniel the Wizard         2004
# 4      Manos: The Hands of Fate         1966

# %%
df[((df["Num_Reviews"] > 100000) | ((df["Rating"] >=8) & (df["Rating"] <= 9)))][["Movie_Title", "Num_Reviews","Rating"]].head()
# Out:
#                   Movie_Title  Num_Reviews  Rating
# 100  The Shawshank Redemption      1829037     9.2
# 101             The Godfather      1249333     9.2
# 102    The Godfather: Part II       860228     9.0
# 103           The Dark Knight      1808543     9.0
# 104              12 Angry Men       497242     8.9
