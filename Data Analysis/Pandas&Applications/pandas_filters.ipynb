# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randint(10,100,45).reshape(15,3)
df = pd.DataFrame(data , columns=["column1", "column2","column3"])
print(df)
# Out:
#     column1  column2  column3
# 0        52       55       51
# 1        68       23       87
# 2        57       60       64
# 3        68       27       87
# 4        31       10       53
# 5        90       70       88
# 6        91       83       66
# 7        71       62       67
# 8        25       70       59
# 9        47       79       33
# 10       69       27       10
# 11       77       79       86
# 12       59       33       45
# 13       80       85       28
# 14       88       34       24

# %%
df.columns
# Out:
# Index(['column1', 'column2', 'column3'], dtype='object')

# %%
#ilk 5 kayıt
df.head()
# Out:
#    column1  column2  column3
# 0       52       55       51
# 1       68       23       87
# 2       57       60       64
# 3       68       27       87
# 4       31       10       53

# %%
df.head(10)  # first 10 line
# Out:
#    column1  column2  column3
# 0       52       55       51
# 1       68       23       87
# 2       57       60       64
# 3       68       27       87
# 4       31       10       53
# 5       90       70       88
# 6       91       83       66
# 7       71       62       67
# 8       25       70       59
# 9       47       79       33

# %%
df.tail()
# Out:
#     column1  column2  column3
# 10       69       27       10
# 11       77       79       86
# 12       59       33       45
# 13       80       85       28
# 14       88       34       24

# %%
df.tail(10)
# Out:
#     column1  column2  column3
# 5        90       70       88
# 6        91       83       66
# 7        71       62       67
# 8        25       70       59
# 9        47       79       33
# 10       69       27       10
# 11       77       79       86
# 12       59       33       45
# 13       80       85       28
# 14       88       34       24

# %%
df["column1"].head()
# Out:
# 0    52
# 1    68
# 2    57
# 3    68
# 4    31
# Name: column1, dtype: int64

# %%
df[["column2", "column2"]].head(10)
# Out:
#    column2  column2
# 0       55       55
# 1       23       23
# 2       60       60
# 3       27       27
# 4       10       10
# 5       70       70
# 6       83       83
# 7       62       62
# 8       70       70
# 9       79       79

# %%
df[0:15][["column2", "column2"]].head()
# Out:
#    column2  column2
# 0       55       55
# 1       23       23
# 2       60       60
# 3       27       27
# 4       10       10

# %%
df[5:15][["column2", "column2"]].head()
# Out:
#    column2  column2
# 5       70       70
# 6       83       83
# 7       62       62
# 8       70       70
# 9       79       79

# %%
df[10:15][["column2", "column2"]].head()
# Out:
#     column2  column2
# 10       27       27
# 11       79       79
# 12       33       33
# 13       85       85
# 14       34       34

# %% [markdown]
# # Filtering on data

# %%
df > 50
# Out:
#     column1  column2  column3
# 0      True     True     True
# 1      True    False     True
# 2      True     True     True
# 3      True    False     True
# 4     False    False     True
# 5      True     True     True
# 6      True     True     True
# 7      True     True     True
# 8     False     True     True
# 9     False     True    False
# 10     True    False    False
# 11     True     True     True
# 12     True    False    False
# 13     True     True    False
# 14     True    False    False

# %%
#True - False değil de değerleri görmek istesek, filtreyi dataframe içerisine veririz
df[df > 50]
# Out:
#     column1  column2  column3
# 0      52.0     55.0     51.0
# 1      68.0      NaN     87.0
# 2      57.0     60.0     64.0
# 3      68.0      NaN     87.0
# 4       NaN      NaN     53.0
# 5      90.0     70.0     88.0
# 6      91.0     83.0     66.0
# 7      71.0     62.0     67.0
# 8       NaN     70.0     59.0
# 9       NaN     79.0      NaN
# 10     69.0      NaN      NaN
# 11     77.0     79.0     86.0
# 12     59.0      NaN      NaN
# 13     80.0     85.0      NaN
# 14     88.0      NaN      NaN

# %%
df[ df %2 == 0 ]  #even numbers
# Out:
#     column1  column2  column3
# 0      52.0      NaN      NaN
# 1      68.0      NaN      NaN
# 2       NaN     60.0     64.0
# 3      68.0      NaN      NaN
# 4       NaN     10.0      NaN
# 5      90.0     70.0     88.0
# 6       NaN      NaN     66.0
# 7       NaN     62.0      NaN
# 8       NaN     70.0      NaN
# 9       NaN      NaN      NaN
# 10      NaN      NaN     10.0
# 11      NaN      NaN     86.0
# 12      NaN      NaN      NaN
# 13     80.0      NaN     28.0
# 14     88.0     34.0     24.0

# %%
df["column1"] > 50
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# Name: column1, dtype: bool

# %%
df[ df["column1"] > 50 ]
#DataFrame'in tamamında column1 sütunundaki değeri 50'den büyük olan satırlar
# Out:
#     column1  column2  column3
# 0        52       55       51
# 1        68       23       87
# 2        57       60       64
# 3        68       27       87
# 5        90       70       88
# 6        91       83       66
# 7        71       62       67
# 10       69       27       10
# 11       77       79       86
# 12       59       33       45
# 13       80       85       28
# 14       88       34       24

# %%
df[ df["column1"] > 50 ]["column1"]
#Sadece column1 sütununun 50'den büyük olan değerler
# Out:
# 0     52
# 1     68
# 2     57
# 3     68
# 5     90
# 6     91
# 7     71
# 10    69
# 11    77
# 12    59
# 13    80
# 14    88
# Name: column1, dtype: int64

# %%
df[(df["column1"] > 18) & (df["column2"] > 60)][["column1","column2"]]
# Out:
#     column1  column2
# 5        90       70
# 6        91       83
# 7        71       62
# 8        25       70
# 9        47       79
# 11       77       79
# 13       80       85

# %%
df[(df["column1"] > 50) | (df["column2"] > 50)][["column1","column2"]].head()
# Out:
#    column1  column2
# 0       52       55
# 1       68       23
# 2       57       60
# 3       68       27
# 5       90       70

# %% [markdown]
# # Query

# %%
df.query("column1 > 50  & column2 > 50 ")[["column1","column2"]].head()
# Out:
#    column1  column2
# 0       52       55
# 2       57       60
# 5       90       70
# 6       91       83
# 7       71       62

# %%
df.query("column1 > 50  | column2 > 50 ")[["column1","column2"]].head()
# Out:
#    column1  column2
# 0       52       55
# 1       68       23
# 2       57       60
# 3       68       27
# 5       90       70
