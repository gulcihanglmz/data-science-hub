# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/youtube-ing.csv")

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
df[5:].head(5)
# Out:
#       video_id trending_date  \
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title       channel_title  \
# 5                       How My Relationship Started!  PointlessBlogVlogs
# 6        Ed Sheeran - Perfect (Official Music Video)          Ed Sheeran
# 7                      CHRISTMAS HAS GONE TO MY HEAD          MoreZoella
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)           ElbowVEVO
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...   JenniferLopezVEVO
#
#    category_id              publish_time  \
# 5           24  2017-11-11T17:00:00.000Z
# 6           10  2017-11-09T11:04:14.000Z
# 7           22  2017-11-10T19:19:43.000Z
# 8           10  2017-11-10T08:00:01.000Z
# 9           10  2017-11-10T15:00:00.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 16

# %%
df.drop(['publish_time', 'description','thumbnail_link', 'comments_disabled'],axis=1,inplace=True)

# %%
df
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
df["likes"].mean()
# Out:
# 134519.55349984582

# %%
df["dislikes"].mean()
# Out:
# 7612.559975331483

# %%
df[["title","likes","dislikes"]].head(20)
# Out:
#                                                 title    likes  dislikes
# 0       John Lewis Christmas Ad 2017 - #MozTheMonster    55681     10247
# 1           Taylor Swift: …Ready for It? (Live) - SNL    25561      2294
# 2          Eminem - Walk On Water (Audio) ft. Beyoncé   787420     43420
# 3   Goals from Salford City vs Class of 92 and Fri...      193        12
# 4   Dashcam captures truck's near miss with child ...       30         2
# 5                        How My Relationship Started!    52708      1431
# 6         Ed Sheeran - Perfect (Official Music Video)  1634124     21082
# 7                       CHRISTMAS HAS GONE TO MY HEAD    57309       749
# 8    Elbow - Golden Slumbers (John Lewis Advert 2017)     2163       147
# 9   Jennifer Lopez - Amor, Amor, Amor (Official Vi...   190084     15015
# 10        CAN BABIES DO GYMNASTICS?  **World Record**     9591       266
# 11  TV Reporter Interviews Alleged Bank Robber, Th...     1746       125
# ...

# %%
df[["title","views"]]
# Out:
#                                                    title     views
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster   7224515
# 1              Taylor Swift: …Ready for It? (Live) - SNL   1053632
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé  17158579
# 3      Goals from Salford City vs Class of 92 and Fri...     27833
# 4      Dashcam captures truck's near miss with child ...      9815
# ...                                                  ...       ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...  25066952
# 38912  Jacob Sartorius - Up With It (Official Music V...   1492219
# 38913                 Anne-Marie - 2002 [Official Video]  29641412
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...  14317515
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...    607552
#
# [38916 rows x 2 columns]

# %%
df[["title","views"]][df["views"] == df["views"].max()]
# Out:
#                                                    title      views
# 28412  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912

# %%
df[["title","views"]][df["views"] == df["views"].max()].iloc[0]
# Out:
# title    Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# views                                            424538912
# Name: 28412, dtype: object

# %%
df[["title","views"]][df["title"] == df["title"].min()]
# Out:
#                                                  title  views
# 146  #21 How to go FAST!!! Coaching famous youtuber...  15466
# 358  #21 How to go FAST!!! Coaching famous youtuber...  15818
# 567  #21 How to go FAST!!! Coaching famous youtuber...  16074

# %%
df[["title","views"]][df["title"] == df["title"].min()].iloc[0]
# Out:
# title    #21 How to go FAST!!! Coaching famous youtuber...
# views                                                15466
# Name: 146, dtype: object

# %%
#top 10 most viewed videos
df["views"].sort_values(ascending=False).head(10)
# Out:
# 28412    424538912
# 28212    413586699
# 28008    402650804
# 27811    392036878
# 27615    382401497
# 27424    372399338
# 27241    362111555
# 27052    349987176
# 26861    339629489
# 34460    337621571
# Name: views, dtype: int64

# %%
df.sort_values("views",ascending=False).head(10)[["title","views"]]
# Out:
#                                                    title      views
# 28412  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912
# 28212  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  413586699
# 28008  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  402650804
# 27811  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  392036878
# 27615  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  382401497
# 27424  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  372399338
# 27241  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  362111555
# 27052  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  349987176
# 26861  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  339629489
# 34460  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571

# %% [markdown]
# **(include=np.number) == (include='number')**

# %%
df.select_dtypes(include='number')
# Out:
#        category_id     views   likes  dislikes  comment_count
# 0               26   7224515   55681     10247           9479
# 1               24   1053632   25561      2294           2757
# 2               10  17158579  787420     43420         125882
# 3               17     27833     193        12             37
# 4               25      9815      30         2             30
# ...            ...       ...     ...       ...            ...
# 38911           10  25066952  268088     12783           9933
# 38912           10   1492219   61998     13781          24330
# 38913           10  29641412  394830      8892          19988
# 38914           24  14317515  151870     45875          26766
# 38915           10    607552   18271       274           1423
#
# [38916 rows x 5 columns]

# %%
df.select_dtypes(include='number').mean()
# Out:
# category_id      1.682794e+01
# views            5.911944e+06
# likes            1.345196e+05
# dislikes         7.612560e+03
# comment_count    1.308835e+04
# dtype: float64

# %%
df.select_dtypes(include=np.number).mean()
# Out:
# category_id      1.682794e+01
# views            5.911944e+06
# likes            1.345196e+05
# dislikes         7.612560e+03
# comment_count    1.308835e+04
# dtype: float64

# %%
df.select_dtypes(include='number')["likes"].mean()
# Out:
# 134519.55349984582

# %%
df.groupby("category_id")[df.select_dtypes(include=np.number).columns].mean()
# Out:
#              category_id         views          likes      dislikes  \
# category_id
# 1                    1.0  3.245133e+06   57205.523089   2403.156383
# 2                    2.0  1.487392e+06   24608.506944   1952.708333
# 10                  10.0  1.244444e+07  272138.508943  11587.191799
# 15                  15.0  1.013709e+06   28629.913858    685.505618
# 17                  17.0  1.752352e+06   39270.313057   5199.032512
# 19                  19.0  1.383177e+06    9674.447917    361.614583
# 20                  20.0  9.768566e+05   39220.127517   1288.846756
# 22                  22.0  1.966606e+06   46273.495899   4102.040328
# 23                  23.0  2.167430e+06   78431.168490   2533.107768
# 24                  24.0  3.264608e+06   81572.362012   9656.526852
# 25                  25.0  1.150311e+06   25021.685714   3085.999184
# 26                  26.0  6.173004e+05   26639.183091    833.606328
# 27                  27.0  9.721894e+05   38440.687090   1297.927790
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df.select_dtypes(include=numerics).mean()
# Out:
# category_id      1.682794e+01
# views            5.911944e+06
# likes            1.345196e+05
# dislikes         7.612560e+03
# comment_count    1.308835e+04
# dtype: float64

# %%
df.select_dtypes(include="number")
# Out:
#        category_id     views   likes  dislikes  comment_count
# 0               26   7224515   55681     10247           9479
# 1               24   1053632   25561      2294           2757
# 2               10  17158579  787420     43420         125882
# 3               17     27833     193        12             37
# 4               25      9815      30         2             30
# ...            ...       ...     ...       ...            ...
# 38911           10  25066952  268088     12783           9933
# 38912           10   1492219   61998     13781          24330
# 38913           10  29641412  394830      8892          19988
# 38914           24  14317515  151870     45875          26766
# 38915           10    607552   18271       274           1423
#
# [38916 rows x 5 columns]

# %%
df.groupby("category_id").sum().sort_values("comment_count",ascending=False)["comment_count"]
# Out:
# category_id
# 10    293013140
# 24    116897440
# 22     18713149
# 23     16718816
# 1      15590011
# 17     10056226
# 25      9386604
# 29      7672790
# 26      7356296
# 20      6166994
# 28      4029065
# 27      1636903
# 15      1404698
# 2        505085
# 19       118177
# 43        80957
# Name: comment_count, dtype: int64

# %%
# number of video by category
df.category_id.value_counts()
# Out:
# category_id
# 10    13754
# 24     9124
# 22     2926
# 1      2577
# 26     1928
# 17     1907
# 23     1828
# 20     1788
# 25     1225
# 15      534
# 28      518
# 27      457
# 2       144
# 19       96
# 29       90
# 43       20
# Name: count, dtype: int64

# %%
df["title_len"] = df["title"].apply(len)
print(df[["title","title_len"]])
# Out:
#                                                    title  title_len
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster         45
# 1              Taylor Swift: …Ready for It? (Live) - SNL         41
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé         42
# 3      Goals from Salford City vs Class of 92 and Fri...         76
# 4      Dashcam captures truck's near miss with child ...         55
# ...                                                  ...        ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...         61
# 38912  Jacob Sartorius - Up With It (Official Music V...         51
# 38913                 Anne-Marie - 2002 [Official Video]         34
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...         75
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...         51
#
# [38916 rows x 2 columns]

# %%
df["tags"]
# Out:
# 0        christmas|"john lewis christmas"|"john lewis"|...
# 1        SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...
# 2        Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# 3        Salford City FC|"Salford City"|"Salford"|"Clas...
# 4                                                   [none]
#                                ...
# 38911    Enrique Iglesias feat. Pitbull|"MOVE TO MIAMI"...
# 38912    jacob sartorius|"jacob"|"up with it"|"jacob sa...
# 38913    anne|"marie"|"anne-marie"|"2002"|"two thousand...
# 38914    Eurovision Song Contest|"2018"|"Lisbon"|"Cypru...
# 38915    Kyle|"SuperDuperKyle"|"Ikuyo"|"2 Chainz"|"Soph...
# Name: tags, Length: 38916, dtype: object

# %% [markdown]
# **Number of tags used for each video**

# %%
data = df["tag_count"] = df["tags"].apply(lambda x : x.split("|"))  #list
print(data)
# Out:
# 0        [christmas, "john lewis christmas", "john lewi...
# 1        [SNL, "Saturday Night Live", "SNL Season 43", ...
# 2        [Eminem, "Walk", "On", "Water", "Aftermath/Sha...
# 3        [Salford City FC, "Salford City", "Salford", "...
# 4                                                 [[none]]
#                                ...
# 38911    [Enrique Iglesias feat. Pitbull, "MOVE TO MIAM...
# 38912    [jacob sartorius, "jacob", "up with it", "jaco...
# 38913    [anne, "marie", "anne-marie", "2002", "two tho...
# 38914    [Eurovision Song Contest, "2018", "Lisbon", "C...
# 38915    [Kyle, "SuperDuperKyle", "Ikuyo", "2 Chainz", ...
# Name: tags, Length: 38916, dtype: object

# %%
df["tag_count"] = df["tags"].apply(lambda x : len(x.split("|")))
print(df["tag_count"])  # number of tags
# Out:
# 0         9
# 1        36
# 2         6
# 3         9
# 4         1
#          ..
# 38911     4
# 38912    41
# 38913    17
# 38914     8
# 38915    18
# Name: tag_count, Length: 38916, dtype: int64

# %%
# second method

def tagCount(tag):
  return len(tag.split("|"))


df["tag_count"] = df["tags"].apply(tagCount)
print(df["tag_count"])
# Out:
# 0         9
# 1        36
# 2         6
# 3         9
# 4         1
#          ..
# 38911     4
# 38912    41
# 38913    17
# 38914     8
# 38915    18
# Name: tag_count, Length: 38916, dtype: int64
